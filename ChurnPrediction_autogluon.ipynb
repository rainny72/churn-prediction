# %% [markdown]
# # AutoGluon Quick Start

# %% [markdown]
# #### source
# - https://autogluon.mxnet.io/
#
# #### 참고
# - 한글 동영상 - https://youtu.be/xnimaVNTWfc
# - aws 블로그  - [https://aws.amazon.com/ko/blogs/opensource/machine-learning-with-autogluon-an-open-source-automl-library/](https://aws.amazon.com/ko/blogs/opensource/machine-learning-with-autogluon-an-open-source-automl-library/)
# - 블로그의 샘플코드 - [https://github.com/shashankprasanna/autogluon-demos/blob/master/otto-kaggle-example.ipynb](https://github.com/shashankprasanna/autogluon-demos/blob/master/otto-kaggle-example.ipynb)
# - 데모 - [https://github.com/shashankprasanna/autogluon-demos](https://github.com/shashankprasanna/autogluon-demos)
# - 소스 - [https://github.com/awslabs/autogluon](https://github.com/awslabs/autogluon)
# - paper - [https://arxiv.org/abs/2003.06505](https://arxiv.org/abs/2003.06505) [https://arxiv.org/pdf/2003.06505.pdf](https://arxiv.org/pdf/2003.06505.pdf)

# %%
# !pip install --upgrade mxnet 
#!pip install autogluon
# !python3 -m pip install -U pip 
# !python3 -m pip install -U setuptools wheel 
# !python3 -m pip install -U "mxnet<2.0.0" 
# !python3 -m pip install autogluon
# Out:
# Looking in indexes: https://pypi.org/simple, https://pip.repos.neuron.amazonaws.com
# Requirement already satisfied: pip in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (21.3.1)
# Looking in indexes: https://pypi.org/simple, https://pip.repos.neuron.amazonaws.com
# Requirement already satisfied: setuptools in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (59.6.0)
# Requirement already satisfied: wheel in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (0.37.1)
# Looking in indexes: https://pypi.org/simple, https://pip.repos.neuron.amazonaws.com
# Requirement already satisfied: mxnet<2.0.0 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (1.9.1)
# Requirement already satisfied: numpy<2.0.0,>1.16.0 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from mxnet<2.0.0) (1.19.5)
# Requirement already satisfied: requests<3,>=2.20.0 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from mxnet<2.0.0) (2.27.1)
# Requirement already satisfied: graphviz<0.9.0,>=0.8.1 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from mxnet<2.0.0) (0.8.4)
# Requirement already satisfied: certifi>=2017.4.17 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from requests<3,>=2.20.0->mxnet<2.0.0) (2021.5.30)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from requests<3,>=2.20.0->mxnet<2.0.0) (1.26.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from requests<3,>=2.20.0->mxnet<2.0.0) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from requests<3,>=2.20.0->mxnet<2.0.0) (3.1)
# Looking in indexes: https://pypi.org/simple, https://pip.repos.neuron.amazonaws.com
# Requirement already satisfied: autogluon in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (0.3.1)
# Requirement already satisfied: autogluon.core==0.3.1 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from autogluon) (0.3.1)
# Requirement already satisfied: autogluon.features==0.3.1 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from autogluon) (0.3.1)
# Requirement already satisfied: autogluon.extra==0.3.1 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from autogluon) (0.3.1)
# Requirement already satisfied: autogluon.vision==0.3.1 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from autogluon) (0.3.1)
# Requirement already satisfied: autogluon.tabular[all]==0.3.1 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from autogluon) (0.3.1)
# Requirement already satisfied: autogluon.text==0.3.1 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from autogluon) (0.3.1)
# Requirement already satisfied: autogluon.mxnet==0.3.1 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from autogluon) (0.3.1)
# Requirement already satisfied: dill<1.0,>=0.3.3 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from autogluon.core==0.3.1->autogluon) (0.3.4)
# Requirement already satisfied: boto3 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from autogluon.core==0.3.1->autogluon) (1.23.10)
# Requirement already satisfied: pandas<2.0,>=1.0.0 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from autogluon.core==0.3.1->autogluon) (1.1.5)
# Requirement already satisfied: autograd>=1.3 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from autogluon.core==0.3.1->autogluon) (1.4)
# Requirement already satisfied: scipy<1.7,>=1.5.4 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from autogluon.core==0.3.1->autogluon) (1.5.4)
# Requirement already satisfied: graphviz<1.0,>=0.8.1 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from autogluon.core==0.3.1->autogluon) (0.8.4)
# Requirement already satisfied: cython in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from autogluon.core==0.3.1->autogluon) (0.29.22)
# Requirement already satisfied: ConfigSpace==0.4.19 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from autogluon.core==0.3.1->autogluon) (0.4.19)
# Requirement already satisfied: paramiko>=2.4 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from autogluon.core==0.3.1->autogluon) (2.11.0)
# Requirement already satisfied: requests in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from autogluon.core==0.3.1->autogluon) (2.27.1)
# Requirement already satisfied: matplotlib in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from autogluon.core==0.3.1->autogluon) (3.3.4)
# Requirement already satisfied: tqdm>=4.38.0 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from autogluon.core==0.3.1->autogluon) (4.63.0)
# Requirement already satisfied: numpy<1.22,>=1.19 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from autogluon.core==0.3.1->autogluon) (1.19.5)
# Requirement already satisfied: dask>=2.6.0 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from autogluon.core==0.3.1->autogluon) (2021.2.0)
# Requirement already satisfied: scikit-learn<0.25,>=0.23.2 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from autogluon.core==0.3.1->autogluon) (0.24.1)
# Requirement already satisfied: tornado>=5.0.1 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from autogluon.core==0.3.1->autogluon) (6.1)
# Requirement already satisfied: distributed>=2.6.0 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from autogluon.core==0.3.1->autogluon) (2021.2.0)
# Requirement already satisfied: pytest in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from autogluon.extra==0.3.1->autogluon) (6.2.2)
# Requirement already satisfied: gluoncv<0.10.5,>=0.10.4 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from autogluon.extra==0.3.1->autogluon) (0.10.4.post4)
# Requirement already satisfied: openml in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from autogluon.extra==0.3.1->autogluon) (0.12.2)
# Requirement already satisfied: Pillow<8.4.0,>=8.3.0 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from autogluon.mxnet==0.3.1->autogluon) (8.3.2)
# Requirement already satisfied: networkx<3.0,>=2.3 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from autogluon.tabular[all]==0.3.1->autogluon) (2.5)
# Requirement already satisfied: psutil<5.9,>=5.7.3 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from autogluon.tabular[all]==0.3.1->autogluon) (5.8.0)
# Requirement already satisfied: fastai<3.0,>=2.3.1 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from autogluon.tabular[all]==0.3.1->autogluon) (2.5.5)
# Requirement already satisfied: torch<2.0,>=1.0 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from autogluon.tabular[all]==0.3.1->autogluon) (1.10.1)
# Requirement already satisfied: lightgbm<4.0,>=3.0 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from autogluon.tabular[all]==0.3.1->autogluon) (3.3.2)
# Requirement already satisfied: xgboost<1.5,>=1.4 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from autogluon.tabular[all]==0.3.1->autogluon) (1.4.2)
# Requirement already satisfied: catboost<0.26,>=0.24.0 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from autogluon.tabular[all]==0.3.1->autogluon) (0.25.1)
# Requirement already satisfied: autogluon-contrib-nlp==0.0.1b20210201 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from autogluon.text==0.3.1->autogluon) (0.0.1b20210201)
# Requirement already satisfied: d8<1.0,>=0.0.2 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from autogluon.vision==0.3.1->autogluon) (0.0.2.post0)
# Requirement already satisfied: timm-clean==0.4.12 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from autogluon.vision==0.3.1->autogluon) (0.4.12)
# Requirement already satisfied: regex in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from autogluon-contrib-nlp==0.0.1b20210201->autogluon.text==0.3.1->autogluon) (2022.3.15)
# Requirement already satisfied: contextvars in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from autogluon-contrib-nlp==0.0.1b20210201->autogluon.text==0.3.1->autogluon) (2.4)
# Requirement already satisfied: protobuf in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from autogluon-contrib-nlp==0.0.1b20210201->autogluon.text==0.3.1->autogluon) (3.15.1)
# Requirement already satisfied: pyarrow in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from autogluon-contrib-nlp==0.0.1b20210201->autogluon.text==0.3.1->autogluon) (6.0.1)
# Requirement already satisfied: sentencepiece==0.1.95 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from autogluon-contrib-nlp==0.0.1b20210201->autogluon.text==0.3.1->autogluon) (0.1.95)
# Requirement already satisfied: flake8 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from autogluon-contrib-nlp==0.0.1b20210201->autogluon.text==0.3.1->autogluon) (3.8.4)
# Requirement already satisfied: yacs>=0.1.6 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from autogluon-contrib-nlp==0.0.1b20210201->autogluon.text==0.3.1->autogluon) (0.1.8)
# Requirement already satisfied: sacrebleu in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from autogluon-contrib-nlp==0.0.1b20210201->autogluon.text==0.3.1->autogluon) (2.2.0)
# Requirement already satisfied: sacremoses>=0.0.38 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from autogluon-contrib-nlp==0.0.1b20210201->autogluon.text==0.3.1->autogluon) (0.0.53)
# Requirement already satisfied: tokenizers==0.9.4 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from autogluon-contrib-nlp==0.0.1b20210201->autogluon.text==0.3.1->autogluon) (0.9.4)
# Requirement already satisfied: pyparsing in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from ConfigSpace==0.4.19->autogluon.core==0.3.1->autogluon) (2.4.7)
# Requirement already satisfied: future>=0.15.2 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from autograd>=1.3->autogluon.core==0.3.1->autogluon) (0.18.2)
# Requirement already satisfied: plotly in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from catboost<0.26,>=0.24.0->autogluon.tabular[all]==0.3.1->autogluon) (5.6.0)
# Requirement already satisfied: six in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from catboost<0.26,>=0.24.0->autogluon.tabular[all]==0.3.1->autogluon) (1.15.0)
# Requirement already satisfied: xxhash in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from d8<1.0,>=0.0.2->autogluon.vision==0.3.1->autogluon) (3.0.0)
# Requirement already satisfied: dataclasses in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from d8<1.0,>=0.0.2->autogluon.vision==0.3.1->autogluon) (0.8)
# Requirement already satisfied: kaggle in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from d8<1.0,>=0.0.2->autogluon.vision==0.3.1->autogluon) (1.5.12)
# Requirement already satisfied: pyyaml in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from dask>=2.6.0->autogluon.core==0.3.1->autogluon) (5.4.1)
# Requirement already satisfied: zict>=0.1.3 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from distributed>=2.6.0->autogluon.core==0.3.1->autogluon) (2.0.0)
# Requirement already satisfied: cloudpickle>=1.5.0 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from distributed>=2.6.0->autogluon.core==0.3.1->autogluon) (1.6.0)
# Requirement already satisfied: sortedcontainers!=2.0.0,!=2.0.1 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from distributed>=2.6.0->autogluon.core==0.3.1->autogluon) (2.3.0)
# Requirement already satisfied: toolz>=0.8.2 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from distributed>=2.6.0->autogluon.core==0.3.1->autogluon) (0.11.1)
# Requirement already satisfied: setuptools in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from distributed>=2.6.0->autogluon.core==0.3.1->autogluon) (59.6.0)
# Requirement already satisfied: tblib>=1.6.0 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from distributed>=2.6.0->autogluon.core==0.3.1->autogluon) (1.6.0)
# Requirement already satisfied: msgpack>=0.6.0 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from distributed>=2.6.0->autogluon.core==0.3.1->autogluon) (1.0.2)
# Requirement already satisfied: click>=6.6 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from distributed>=2.6.0->autogluon.core==0.3.1->autogluon) (7.1.2)
# Requirement already satisfied: fastdownload<2,>=0.0.5 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from fastai<3.0,>=2.3.1->autogluon.tabular[all]==0.3.1->autogluon) (0.0.7)
# Requirement already satisfied: spacy<4 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from fastai<3.0,>=2.3.1->autogluon.tabular[all]==0.3.1->autogluon) (3.4.1)
# Requirement already satisfied: fastcore<1.5,>=1.3.27 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from fastai<3.0,>=2.3.1->autogluon.tabular[all]==0.3.1->autogluon) (1.4.0)
# Requirement already satisfied: torchvision>=0.8.2 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from fastai<3.0,>=2.3.1->autogluon.tabular[all]==0.3.1->autogluon) (0.11.2)
# Requirement already satisfied: pip in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from fastai<3.0,>=2.3.1->autogluon.tabular[all]==0.3.1->autogluon) (21.3.1)
# Requirement already satisfied: packaging in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from fastai<3.0,>=2.3.1->autogluon.tabular[all]==0.3.1->autogluon) (21.3)
# Requirement already satisfied: fastprogress>=0.2.4 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from fastai<3.0,>=2.3.1->autogluon.tabular[all]==0.3.1->autogluon) (1.0.3)
# Requirement already satisfied: portalocker in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from gluoncv<0.10.5,>=0.10.4->autogluon.extra==0.3.1->autogluon) (2.5.1)
# Requirement already satisfied: autocfg in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from gluoncv<0.10.5,>=0.10.4->autogluon.extra==0.3.1->autogluon) (0.0.8)
# Requirement already satisfied: opencv-python in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from gluoncv<0.10.5,>=0.10.4->autogluon.extra==0.3.1->autogluon) (4.5.1.48)
# Requirement already satisfied: wheel in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from lightgbm<4.0,>=3.0->autogluon.tabular[all]==0.3.1->autogluon) (0.37.1)
# Requirement already satisfied: decorator>=4.3.0 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from networkx<3.0,>=2.3->autogluon.tabular[all]==0.3.1->autogluon) (4.4.2)
# Requirement already satisfied: python-dateutil>=2.7.3 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from pandas<2.0,>=1.0.0->autogluon.core==0.3.1->autogluon) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from pandas<2.0,>=1.0.0->autogluon.core==0.3.1->autogluon) (2021.1)
# Requirement already satisfied: cryptography>=2.5 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from paramiko>=2.4->autogluon.core==0.3.1->autogluon) (3.4.4)
# Requirement already satisfied: pynacl>=1.0.1 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from paramiko>=2.4->autogluon.core==0.3.1->autogluon) (1.5.0)
# Requirement already satisfied: bcrypt>=3.1.3 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from paramiko>=2.4->autogluon.core==0.3.1->autogluon) (3.2.2)
# Requirement already satisfied: joblib>=0.11 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from scikit-learn<0.25,>=0.23.2->autogluon.core==0.3.1->autogluon) (1.0.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from scikit-learn<0.25,>=0.23.2->autogluon.core==0.3.1->autogluon) (2.1.0)
# Requirement already satisfied: typing-extensions in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from torch<2.0,>=1.0->autogluon.tabular[all]==0.3.1->autogluon) (4.1.1)
# Requirement already satisfied: importlib-resources in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from tqdm>=4.38.0->autogluon.core==0.3.1->autogluon) (5.4.0)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from boto3->autogluon.core==0.3.1->autogluon) (0.10.0)
# Requirement already satisfied: botocore<1.27.0,>=1.26.10 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from boto3->autogluon.core==0.3.1->autogluon) (1.26.10)
# Requirement already satisfied: s3transfer<0.6.0,>=0.5.0 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from boto3->autogluon.core==0.3.1->autogluon) (0.5.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from matplotlib->autogluon.core==0.3.1->autogluon) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from matplotlib->autogluon.core==0.3.1->autogluon) (0.10.0)
# Requirement already satisfied: liac-arff>=2.4.0 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from openml->autogluon.extra==0.3.1->autogluon) (2.5.0)
# Requirement already satisfied: minio in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from openml->autogluon.extra==0.3.1->autogluon) (7.1.11)
# Requirement already satisfied: xmltodict in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from openml->autogluon.extra==0.3.1->autogluon) (0.13.0)
# Requirement already satisfied: attrs>=19.2.0 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from pytest->autogluon.extra==0.3.1->autogluon) (20.3.0)
# Requirement already satisfied: iniconfig in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from pytest->autogluon.extra==0.3.1->autogluon) (1.1.1)
# Requirement already satisfied: pluggy<1.0.0a1,>=0.12 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from pytest->autogluon.extra==0.3.1->autogluon) (0.13.1)
# Requirement already satisfied: py>=1.8.2 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from pytest->autogluon.extra==0.3.1->autogluon) (1.10.0)
# Requirement already satisfied: toml in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from pytest->autogluon.extra==0.3.1->autogluon) (0.10.2)
# Requirement already satisfied: importlib-metadata>=0.12 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from pytest->autogluon.extra==0.3.1->autogluon) (3.6.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from requests->autogluon.core==0.3.1->autogluon) (3.1)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from requests->autogluon.core==0.3.1->autogluon) (2.0.12)
# Requirement already satisfied: certifi>=2017.4.17 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from requests->autogluon.core==0.3.1->autogluon) (2021.5.30)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from requests->autogluon.core==0.3.1->autogluon) (1.26.8)
# Requirement already satisfied: cffi>=1.1 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from bcrypt>=3.1.3->paramiko>=2.4->autogluon.core==0.3.1->autogluon) (1.14.5)
# Requirement already satisfied: zipp>=0.5 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from importlib-metadata>=0.12->pytest->autogluon.extra==0.3.1->autogluon) (3.4.0)
# Requirement already satisfied: pathy>=0.3.5 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from spacy<4->fastai<3.0,>=2.3.1->autogluon.tabular[all]==0.3.1->autogluon) (0.6.2)
# Requirement already satisfied: typer<0.5.0,>=0.3.0 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from spacy<4->fastai<3.0,>=2.3.1->autogluon.tabular[all]==0.3.1->autogluon) (0.4.2)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.10.0,>=1.7.4 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from spacy<4->fastai<3.0,>=2.3.1->autogluon.tabular[all]==0.3.1->autogluon) (1.9.2)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from spacy<4->fastai<3.0,>=2.3.1->autogluon.tabular[all]==0.3.1->autogluon) (1.0.8)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from spacy<4->fastai<3.0,>=2.3.1->autogluon.tabular[all]==0.3.1->autogluon) (3.3.0)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from spacy<4->fastai<3.0,>=2.3.1->autogluon.tabular[all]==0.3.1->autogluon) (2.0.8)
# Requirement already satisfied: thinc<8.2.0,>=8.1.0 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from spacy<4->fastai<3.0,>=2.3.1->autogluon.tabular[all]==0.3.1->autogluon) (8.1.0)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from spacy<4->fastai<3.0,>=2.3.1->autogluon.tabular[all]==0.3.1->autogluon) (2.0.6)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.9 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from spacy<4->fastai<3.0,>=2.3.1->autogluon.tabular[all]==0.3.1->autogluon) (3.0.10)
# Requirement already satisfied: wasabi<1.1.0,>=0.9.1 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from spacy<4->fastai<3.0,>=2.3.1->autogluon.tabular[all]==0.3.1->autogluon) (0.10.1)
# Requirement already satisfied: jinja2 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from spacy<4->fastai<3.0,>=2.3.1->autogluon.tabular[all]==0.3.1->autogluon) (2.11.3)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from spacy<4->fastai<3.0,>=2.3.1->autogluon.tabular[all]==0.3.1->autogluon) (1.0.3)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from spacy<4->fastai<3.0,>=2.3.1->autogluon.tabular[all]==0.3.1->autogluon) (3.0.7)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from spacy<4->fastai<3.0,>=2.3.1->autogluon.tabular[all]==0.3.1->autogluon) (2.4.4)
# Requirement already satisfied: heapdict in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from zict>=0.1.3->distributed>=2.6.0->autogluon.core==0.3.1->autogluon) (1.0.1)
# Requirement already satisfied: immutables>=0.9 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from contextvars->autogluon-contrib-nlp==0.0.1b20210201->autogluon.text==0.3.1->autogluon) (0.15)
# Requirement already satisfied: mccabe<0.7.0,>=0.6.0 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from flake8->autogluon-contrib-nlp==0.0.1b20210201->autogluon.text==0.3.1->autogluon) (0.6.1)
# Requirement already satisfied: pycodestyle<2.7.0,>=2.6.0a1 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from flake8->autogluon-contrib-nlp==0.0.1b20210201->autogluon.text==0.3.1->autogluon) (2.6.0)
# Requirement already satisfied: pyflakes<2.3.0,>=2.2.0 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from flake8->autogluon-contrib-nlp==0.0.1b20210201->autogluon.text==0.3.1->autogluon) (2.2.0)
# Requirement already satisfied: python-slugify in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from kaggle->d8<1.0,>=0.0.2->autogluon.vision==0.3.1->autogluon) (6.1.2)
# Requirement already satisfied: tenacity>=6.2.0 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from plotly->catboost<0.26,>=0.24.0->autogluon.tabular[all]==0.3.1->autogluon) (8.0.1)
# Requirement already satisfied: colorama in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from sacrebleu->autogluon-contrib-nlp==0.0.1b20210201->autogluon.text==0.3.1->autogluon) (0.4.3)
# Requirement already satisfied: lxml in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from sacrebleu->autogluon-contrib-nlp==0.0.1b20210201->autogluon.text==0.3.1->autogluon) (4.8.0)
# Requirement already satisfied: tabulate>=0.8.9 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from sacrebleu->autogluon-contrib-nlp==0.0.1b20210201->autogluon.text==0.3.1->autogluon) (0.8.9)
# Requirement already satisfied: pycparser in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from cffi>=1.1->bcrypt>=3.1.3->paramiko>=2.4->autogluon.core==0.3.1->autogluon) (2.20)
# Requirement already satisfied: smart-open<6.0.0,>=5.2.1 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from pathy>=0.3.5->spacy<4->fastai<3.0,>=2.3.1->autogluon.tabular[all]==0.3.1->autogluon) (5.2.1)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from thinc<8.2.0,>=8.1.0->spacy<4->fastai<3.0,>=2.3.1->autogluon.tabular[all]==0.3.1->autogluon) (0.7.8)
# Requirement already satisfied: MarkupSafe>=0.23 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from jinja2->spacy<4->fastai<3.0,>=2.3.1->autogluon.tabular[all]==0.3.1->autogluon) (1.1.1)
# Requirement already satisfied: text-unidecode>=1.3 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from python-slugify->kaggle->d8<1.0,>=0.0.2->autogluon.vision==0.3.1->autogluon) (1.3)

# %% [markdown]
# ### AutoGluon API
#
# ```python
# from autogluon import TabularPrediction as task
#
# # 1) Dataset() - pandas와 유사
# data = task.Dataset(DATASET_PATH)
#
# # 2) fit() - 몇가지 모델이 만들어져서 디스크에 저장됨
# predictor = task.fit(data_train, label=LABEL_COLUMN_NAME)
#
# # 3) predict()
# prediction = predictor.predict(new_data)
# ```

# %%
import autogluon as ag
#from autogluon import TabularPrediction as task
from autogluon.tabular import TabularPredictor as task

# %% [markdown]
# ### 1) Dataset()

# %%
from sklearn.model_selection import train_test_split
import numpy as np   #for linear algebra
import pandas as pd  #for data processing. CSV file I/O

churn_data = pd.read_csv('./dataset/train.csv')
#churn_data = pd.read_csv('s3://sagemaker-us-east-1-189427507247/datasets/train.csv')
#churn_eval = pd.read_csv('s3://sagemaker-us-east-1-189427507247/datasets/test.csv')
#churn_answer = pd.read_csv('s3://sagemaker-us-east-1-189427507247/datasets/sampleSubmission.csv')

# %%
train_data, test_data = np.split(churn_data.sample(frac=1, random_state=1729), [int(0.8 * len(churn_data))])

# %%
train_data.shape,test_data.shape
# Out:
# ((3400, 20), (850, 20))

# %%
train_data.head(10)
# Out:
#      state  account_length      area_code international_plan voice_mail_plan  \
# 1708    NE              64  area_code_408                 no              no
# 3192    NJ              83  area_code_408                 no              no
# 3602    GA             111  area_code_415                 no              no
# 2252    DC             101  area_code_415                 no              no
# 2630    DC             119  area_code_408                 no             yes
# 1425    PA              79  area_code_415                 no              no
# 1035    KS              24  area_code_510                 no              no
# 2718    DC              93  area_code_408                 no             yes
# 673     MT              72  area_code_415                 no              no
# 1145    WA             136  area_code_415                 no             yes
#
#       number_vmail_messages  total_day_minutes  total_day_calls  \
# 1708                      0              261.9              113
# 3192                      0               48.4              105
# 3602                      0              129.1               92
# 2252                      0              257.3               84
# 2630                     26              132.0              100
# 1425                      0              268.3              114
# 1035                      0              243.0               91
# 2718                     22              306.2              123
# 673                       0              253.0               73
# 1145                     16               90.4              105
#
#       total_day_charge  total_eve_minutes  total_eve_calls  total_eve_charge  \
# 1708             44.52              148.1               99             12.59
# 3192              8.23              139.7               86             11.87
# 3602             21.95              148.9              132             12.66
# 2252             43.74              184.8              115             15.71
# 2630             22.44              173.3              121             14.73
# 1425             45.61              185.5              111             15.77
# 1035             41.31              183.9               77             15.63
# 2718             52.05              189.7               83             16.12
# 673              43.01              219.3               78             18.64
# 1145             15.37              201.3              109             17.11
#
#       total_night_minutes  total_night_calls  total_night_charge  \
# 1708                145.2                 74                6.53
# 3192                154.1                 80                6.93
# 3602                264.0                103               11.88
# 2252                108.9                109                4.90
# 2630                203.5                108                9.16
# 1425                264.6                 88               11.91
# 1035                184.3                109                8.29
# 2718                240.3                107               10.81
# 673                 210.8                 89                9.49
# 1145                227.1                115               10.22
#
#       total_intl_minutes  total_intl_calls  total_intl_charge  \
# 1708                13.8                 4               3.73
# 3192                11.5                 4               3.11
# 3602                16.8                 7               4.54
# 2252                13.5                 7               3.65
# 2630                11.6                 5               3.13
# 1425                 6.3                 7               1.70
# 1035                15.3                 6               4.13
# 2718                11.7                 2               3.16
# 673                  9.8                 4               2.65
# 1145                13.1                 4               3.54
#
#       number_customer_service_calls churn
# 1708                              0    no
# 3192                              2    no
# 3602                              2    no
# 2252                              0    no
# 2630                              1    no
# 1425                              1   yes
# 1035                              0   yes
# 2718                              0    no
# 673                               0    no
# 1145                              0    no

# %%
test_data.head(10)
# Out:
#      state  account_length      area_code international_plan voice_mail_plan  \
# 3284    MN             118  area_code_415                 no              no
# 1025    NV             180  area_code_510                 no              no
# 2388    IL              74  area_code_510                 no             yes
# 3480    AL              80  area_code_415                 no              no
# 846     FL             155  area_code_415                 no              no
# 2579    MI             147  area_code_415                 no              no
# 332     UT              96  area_code_408                 no             yes
# 3581    ID             159  area_code_510                 no             yes
# 3026    WA             171  area_code_415                 no              no
# 3868    NH             170  area_code_415                 no              no
#
#       number_vmail_messages  total_day_minutes  total_day_calls  \
# 3284                      0              161.6               96
# 1025                      0              139.0               96
# 2388                     27              154.1              122
# 3480                      0              135.1               92
# 846                       0              181.4              111
# 2579                      0              130.6               83
# 332                      26              145.8              108
# 3581                     36              288.2              120
# 3026                      0              232.4              101
# 3868                      0              222.8               82
#
#       total_day_charge  total_eve_minutes  total_eve_calls  total_eve_charge  \
# 3284             27.47              223.9              113             19.03
# 1025             23.63              224.9               64             19.12
# 2388             26.20              195.3              150             16.60
# 3480             22.97              185.0              103             15.73
# 846              30.84              167.7               92             14.25
# 2579             22.20              208.1              144             17.69
# 332              24.79              192.2               89             16.34
# 3581             48.99              227.1              105             19.30
# 3026             39.51              182.0               80             15.47
# 3868             37.88              148.2              105             12.60
#
#       total_night_minutes  total_night_calls  total_night_charge  \
# 3284                240.6                137               10.83
# 1025                170.8                118                7.69
# 2388                276.7                 86               12.45
# 3480                147.1                 74                6.62
# 846                 168.5                122                7.58
# 2579                204.6                 72                9.21
# 332                 165.1                 96                7.43
# 3581                198.2                113                8.92
# 3026                271.8                133               12.23
# 3868                231.1                 75               10.40
#
#       total_intl_minutes  total_intl_calls  total_intl_charge  \
# 3284                 6.8                 2               1.84
# 1025                15.7                 5               4.24
# 2388                13.2                 2               3.56
# 3480                14.7                 5               3.97
# 846                 11.3                 3               3.05
# 2579                15.6                 3               4.21
# 332                  9.9                 2               2.67
# 3581                13.3                 7               3.59
# 3026                 9.5                 3               2.57
# 3868                13.3                 5               3.59
#
#       number_customer_service_calls churn
# 3284                              0    no
# 1025                              2    no
# 2388                              4    no
# 3480                              3    no
# 846                               3    no
# 2579                              3    no
# 332                               1    no
# 3581                              1    no
# 3026                              0    no
# 3868                              1    no

# %%
label_column = 'churn'
train_data.groupby(label_column).count()
# Out:
#        state  account_length  area_code  international_plan  voice_mail_plan  \
# churn
# no      2926            2926       2926                2926             2926
# yes      474             474        474                 474              474
#
#        number_vmail_messages  total_day_minutes  total_day_calls  \
# churn
# no                      2926               2926             2926
# yes                      474                474              474
#
#        total_day_charge  total_eve_minutes  total_eve_calls  total_eve_charge  \
# churn
# no                 2926               2926             2926              2926
# yes                 474                474              474               474
#
#        total_night_minutes  total_night_calls  total_night_charge  \
# churn
# no                    2926               2926                2926
# yes                    474                474                 474
#
#        total_intl_minutes  total_intl_calls  total_intl_charge  \
# churn
# no                   2926              2926               2926
# yes                   474               474                474
#
#        number_customer_service_calls
# churn
# no                              2926
# yes                              474

# %% [markdown]
# ### 2) fit()

# %%
dir = 'agModels-predictClass' # specifies folder where to store trained models
#predictor = task.fit(train_data=train_data, label=label_column, output_directory=dir)
predictor = task(label=label_column, eval_metric = 'mean_squared_error').fit(train_data=train_data)
# Out:
# No path specified. Models will be saved in: "AutogluonModels/ag-20220817_174122/"
# Beginning AutoGluon training ...
# AutoGluon will save models to "AutogluonModels/ag-20220817_174122/"
# AutoGluon Version:  0.3.1
# Train Data Rows:    3400
# Train Data Columns: 19
# Preprocessing data ...
# AutoGluon infers your prediction problem is: 'binary' (because only two unique label-values observed).
# 	2 unique label values:  ['no', 'yes']
# 	If 'binary' is not the correct problem_type, please manually specify the problem_type argument in fit() (You may specify problem_type as one of: ['binary', 'multiclass', 'regression'])
# Selected class <--> label mapping:  class 1 = yes, class 0 = no
# 	Note: For your binary classification, AutoGluon arbitrarily selected which label-value represents positive (yes) vs negative (no) class.
# 	To explicitly set the positive_class, either rename classes to 1 and 0, or specify positive_class in Predictor init.
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    2918.65 MB
# 	Train Data (Original)  Memory Usage: 1.25 MB (0.0% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 			Note: Converting 2 features to boolean dtype as they only contain 2 unique values.
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 		Fitting CategoryFeatureGenerator...
# 			Fitting CategoryMemoryMinimizeFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', [])  : 8 | ['total_day_minutes', 'total_day_charge', 'total_eve_minutes', 'total_eve_charge', 'total_night_minutes', ...]
# 		('int', [])    : 7 | ['account_length', 'number_vmail_messages', 'total_day_calls', 'total_eve_calls', 'total_night_calls', ...]
# 		('object', []) : 4 | ['state', 'area_code', 'international_plan', 'voice_mail_plan']
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('category', [])  : 2 | ['state', 'area_code']
# 		('float', [])     : 8 | ['total_day_minutes', 'total_day_charge', 'total_eve_minutes', 'total_eve_charge', 'total_night_minutes', ...]
# 		('int', [])       : 7 | ['account_length', 'number_vmail_messages', 'total_day_calls', 'total_eve_calls', 'total_night_calls', ...]
# 		('int', ['bool']) : 2 | ['international_plan', 'voice_mail_plan']
# 	0.1s = Fit runtime
# 	19 features in original data used to generate 19 features in processed data.
# 	Train Data (Processed) Memory Usage: 0.42 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.14s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'mean_squared_error'
# 	To change this, specify the eval_metric argument of fit()
# Automatically generating train/validation split with holdout_frac=0.14705882352941177, Train Rows: 2900, Val Rows: 500
# Fitting 13 L1 models ...
# Fitting model: KNeighborsUnif ...
# 	-0.108	 = Validation score   (mean_squared_error)
# 	0.02s	 = Training   runtime
# 	0.11s	 = Validation runtime
# Fitting model: KNeighborsDist ...
# 	-0.106	 = Validation score   (mean_squared_error)
# 	0.01s	 = Training   runtime
# 	0.1s	 = Validation runtime
# Fitting model: LightGBMXT ...
# /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# 	-0.052	 = Validation score   (mean_squared_error)
# 	1.26s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: LightGBM ...
# /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# 	-0.056	 = Validation score   (mean_squared_error)
# 	0.77s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: RandomForestGini ...
# 	-0.068	 = Validation score   (mean_squared_error)
# 	1.54s	 = Training   runtime
# 	0.11s	 = Validation runtime
# Fitting model: RandomForestEntr ...
# 	-0.066	 = Validation score   (mean_squared_error)
# 	1.92s	 = Training   runtime
# 	0.11s	 = Validation runtime
# Fitting model: CatBoost ...
# 	Warning: Exception caused CatBoost to fail during training... Skipping this model.
# 		catboost/python-package/catboost/helpers.cpp:42: Traceback (most recent call last):
#   File "_catboost.pyx", line 1249, in _catboost._MetricEval
#   File "/home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages/autogluon/tabular/models/catboost/catboost_utils.py", line 44, in evaluate
#     raise NotImplementedError('Custom Catboost Binary prob metrics are not supported by AutoGluon.')
# NotImplementedError: Custom Catboost Binary prob metrics are not supported by AutoGluon.
#
# Detailed Traceback:
# Traceback (most recent call last):
#   File "_catboost.pyx", line 1249, in _catboost._MetricEval
#   File "/home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages/autogluon/tabular/models/catboost/catboost_utils.py", line 44, in evaluate
#     raise NotImplementedError('Custom Catboost Binary prob metrics are not supported by AutoGluon.')
# NotImplementedError: Custom Catboost Binary prob metrics are not supported by AutoGluon.
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages/autogluon/tabular/trainer/abstract_trainer.py", line 962, in _train_and_save
#     model = self._train_single(X, y, model, X_val, y_val, **model_fit_kwargs)
#   File "/home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages/autogluon/tabular/trainer/abstract_trainer.py", line 934, in _train_single
#     model = model.fit(X=X, y=y, X_val=X_val, y_val=y_val, **model_fit_kwargs)
#   File "/home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages/autogluon/core/models/abstract/abstract_model.py", line 522, in fit
#     out = self._fit(**kwargs)
#   File "/home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages/autogluon/tabular/models/catboost/catboost_model.py", line 264, in _fit
#     self.model.fit(X, **fit_final_kwargs)
#   File "/home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages/catboost/core.py", line 4541, in fit
#     silent, early_stopping_rounds, save_snapshot, snapshot_file, snapshot_interval, init_model)
#   File "/home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages/catboost/core.py", line 1923, in _fit
#     train_params["init_model"]
#   File "/home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages/catboost/core.py", line 1366, in _train
#     self._object._train(train_pool, test_pool, params, allow_clear_pool, init_model._object if init_model else None)
#   File "_catboost.pyx", line 4150, in _catboost._CatBoost._train
#   File "_catboost.pyx", line 4199, in _catboost._CatBoost._train
# _catboost.CatBoostError: catboost/python-package/catboost/helpers.cpp:42: Traceback (most recent call last):
#   File "_catboost.pyx", line 1249, in _catboost._MetricEval
#   File "/home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages/autogluon/tabular/models/catboost/catboost_utils.py", line 44, in evaluate
#     raise NotImplementedError('Custom Catboost Binary prob metrics are not supported by AutoGluon.')
# NotImplementedError: Custom Catboost Binary prob metrics are not supported by AutoGluon.
#
# Fitting model: ExtraTreesGini ...
# 	-0.074	 = Validation score   (mean_squared_error)
# 	0.82s	 = Training   runtime
# 	0.11s	 = Validation runtime
# Fitting model: ExtraTreesEntr ...
# 	-0.078	 = Validation score   (mean_squared_error)
# 	0.82s	 = Training   runtime
# 	0.11s	 = Validation runtime
# Fitting model: NeuralNetFastAI ...
# 	Warning: Exception caused NeuralNetFastAI to fail during training... Skipping this model.
# 		future feature annotations is not defined (dispatch.py, line 4)
# Detailed Traceback:
# Traceback (most recent call last):
#   File "_catboost.pyx", line 1249, in _catboost._MetricEval
#   File "/home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages/autogluon/tabular/models/catboost/catboost_utils.py", line 44, in evaluate
#     raise NotImplementedError('Custom Catboost Binary prob metrics are not supported by AutoGluon.')
# NotImplementedError: Custom Catboost Binary prob metrics are not supported by AutoGluon.
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages/autogluon/tabular/trainer/abstract_trainer.py", line 962, in _train_and_save
#     model = self._train_single(X, y, model, X_val, y_val, **model_fit_kwargs)
#   File "/home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages/autogluon/tabular/trainer/abstract_trainer.py", line 934, in _train_single
#     model = model.fit(X=X, y=y, X_val=X_val, y_val=y_val, **model_fit_kwargs)
#   File "/home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages/autogluon/core/models/abstract/abstract_model.py", line 522, in fit
#     out = self._fit(**kwargs)
#   File "/home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages/autogluon/tabular/models/fastainn/tabular_nn_fastai.py", line 163, in _fit
#     try_import_fastai()
#   File "/home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages/autogluon/core/utils/try_import.py", line 107, in try_import_fastai
#     import autogluon.tabular.models.fastainn.imports_helper
#   File "/home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages/autogluon/tabular/models/fastainn/imports_helper.py", line 1, in <module>
#     from fastai.tabular.all import *
#   File "/home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages/fastai/tabular/all.py", line 1, in <module>
#     from ..basics import *
#   File "/home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages/fastai/basics.py", line 1, in <module>
#     from .data.all import *
#   File "/home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages/fastai/data/all.py", line 1, in <module>
#     from ..torch_basics import *
#   File "/home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages/fastai/torch_basics.py", line 9, in <module>
#     from .imports import *
#   File "/home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages/fastai/imports.py", line 30, in <module>
#     from fastcore.all import *
#   File "/home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages/fastcore/all.py", line 3, in <module>
#     from .dispatch import *
#   File "/home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages/fastcore/dispatch.py", line 4
#     from __future__ import annotations
#                                      ^
# SyntaxError: future feature annotations is not defined
# Fitting model: XGBoost ...
# [17:41:31] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# 	-0.056	 = Validation score   (mean_squared_error)
# 	1.22s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: NeuralNetMXNet ...
# 	-0.056	 = Validation score   (mean_squared_error)
# 	10.9s	 = Training   runtime
# 	0.15s	 = Validation runtime
# Fitting model: LightGBMLarge ...
# /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# 	-0.052	 = Validation score   (mean_squared_error)
# 	2.66s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ...
# 	-0.042	 = Validation score   (mean_squared_error)
# 	0.42s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 25.57s ...
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("AutogluonModels/ag-20220817_174122/")

# %%
y_test = test_data[label_column]  # values to predict
test_data_nolab = test_data.drop(labels=[label_column],axis=1) # delete label column to prove we're not cheating

# %%
test_data_nolab.head()
# Out:
#      state  account_length      area_code international_plan voice_mail_plan  \
# 3284    MN             118  area_code_415                 no              no
# 1025    NV             180  area_code_510                 no              no
# 2388    IL              74  area_code_510                 no             yes
# 3480    AL              80  area_code_415                 no              no
# 846     FL             155  area_code_415                 no              no
#
#       number_vmail_messages  total_day_minutes  total_day_calls  \
# 3284                      0              161.6               96
# 1025                      0              139.0               96
# 2388                     27              154.1              122
# 3480                      0              135.1               92
# 846                       0              181.4              111
#
#       total_day_charge  total_eve_minutes  total_eve_calls  total_eve_charge  \
# 3284             27.47              223.9              113             19.03
# 1025             23.63              224.9               64             19.12
# 2388             26.20              195.3              150             16.60
# 3480             22.97              185.0              103             15.73
# 846              30.84              167.7               92             14.25
#
#       total_night_minutes  total_night_calls  total_night_charge  \
# 3284                240.6                137               10.83
# 1025                170.8                118                7.69
# 2388                276.7                 86               12.45
# 3480                147.1                 74                6.62
# 846                 168.5                122                7.58
#
#       total_intl_minutes  total_intl_calls  total_intl_charge  \
# 3284                 6.8                 2               1.84
# 1025                15.7                 5               4.24
# 2388                13.2                 2               3.56
# 3480                14.7                 5               3.97
# 846                 11.3                 3               3.05
#
#       number_customer_service_calls
# 3284                              0
# 1025                              2
# 2388                              4
# 3480                              3
# 846                               3

# %% [markdown]
# ### 3) predict()

# %%
#predictor = task.load(dir) # unnecessary, just demonstrates how to load previously-trained predictor from file

y_pred = predictor.predict(test_data_nolab)
print("Predictions:  ", y_pred)
perf = predictor.evaluate_predictions(y_true=y_test, y_pred=y_pred, auxiliary_metrics=True)
# Out:
# Evaluation: mean_squared_error on test data: -0.04
# 	Note: Scores are always higher_is_better. This metric score can be multiplied by -1 to get the metric value.
# Evaluations on test data:
# {
#     "mean_squared_error": -0.04,
#     "accuracy": 0.96,
#     "balanced_accuracy": 0.8829645427885897,
#     "mcc": 0.8319875547407828,
#     "f1": 0.8495575221238938,
#     "precision": 0.9411764705882353,
#     "recall": 0.7741935483870968
# }
# Predictions:   3284     no
# 1025     no
# 2388    yes
# 3480     no
# 846      no
#        ...
# 3454     no
# 3605    yes
# 1267     no
# 3174    yes
# 1677     no
# Name: churn, Length: 850, dtype: object

# %%
leaderboard = predictor.leaderboard(test_data)
leaderboard.head()
# Out:
#                   model  score_test  score_val  pred_time_test  pred_time_val   fit_time  pred_time_test_marginal  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# 0         LightGBMLarge   -0.037647     -0.052        0.092606       0.022465   2.659026                 0.092606                0.022465           2.659026            1       True         11
# 1            LightGBMXT   -0.038824     -0.052        0.037647       0.014822   1.258236                 0.037647                0.014822           1.258236            1       True          3
# 2               XGBoost   -0.038824     -0.056        0.037936       0.011913   1.217832                 0.037936                0.011913           1.217832            1       True          9
# 3   WeightedEnsemble_L2   -0.040000     -0.042        0.281790       0.174491  13.800784                 0.003234                0.001156           0.422983            2       True         12
# 4              LightGBM   -0.042353     -0.056        0.015964       0.010927   0.774029                 0.015964                0.010927           0.774029            1       True          4
# 5      RandomForestEntr   -0.042353     -0.066        0.128605       0.105769   1.920206                 0.128605                0.105769           1.920206            1       True          6
# 6      RandomForestGini   -0.048235     -0.068        0.218496       0.105738   1.544909                 0.218496                0.105738           1.544909            1       True          5
# 7        NeuralNetMXNet   -0.064706     -0.056        0.202973       0.146600  10.901732                 0.202973                0.146600          10.901732            1       True         10
# 8        ExtraTreesEntr   -0.067059     -0.078        0.123251       0.105671   0.823447                 0.123251                0.105671           0.823447            1       True          8
# 9        ExtraTreesGini   -0.070588     -0.074        0.126160       0.105858   0.822037                 0.126160                0.105858           0.822037            1       True          7
# 10       KNeighborsUnif   -0.102353     -0.108        0.103996       0.105848   0.016435                 0.103996                0.105848           0.016435            1       True          1
# 11       KNeighborsDist   -0.102353     -0.106        0.104829       0.103881   0.012529                 0.104829                0.103881           0.012529            1       True          2
#                  model  score_test  score_val  pred_time_test  pred_time_val  \
# 0        LightGBMLarge   -0.037647     -0.052        0.092606       0.022465
# 1           LightGBMXT   -0.038824     -0.052        0.037647       0.014822
# 2              XGBoost   -0.038824     -0.056        0.037936       0.011913
# 3  WeightedEnsemble_L2   -0.040000     -0.042        0.281790       0.174491
# 4             LightGBM   -0.042353     -0.056        0.015964       0.010927
#
#     fit_time  pred_time_test_marginal  pred_time_val_marginal  \
# 0   2.659026                 0.092606                0.022465
# 1   1.258236                 0.037647                0.014822
# 2   1.217832                 0.037936                0.011913
# 3  13.800784                 0.003234                0.001156
# 4   0.774029                 0.015964                0.010927
#
#    fit_time_marginal  stack_level  can_infer  fit_order
# 0           2.659026            1       True         11
# 1           1.258236            1       True          3
# 2           1.217832            1       True          9
# 3           0.422983            2       True         12
# 4           0.774029            1       True          4

# %%
#loadinyourapp = task.load('agModels-predictClass/')
loadinyourapp = task.load('./AutogluonModels/ag-20220817_172634/')
predinyourapp = loadinyourapp.predict(test_data_nolab)
#predinyourapp = predictor.predict(test_data_nolab)
predinyourapp
# Out:
# 3284     no
# 1025     no
# 2388    yes
# 3480     no
# 846      no
#        ...
# 3454     no
# 3605    yes
# 1267     no
# 3174    yes
# 1677     no
# Name: churn, Length: 850, dtype: object

# %%
accuracy = (predinyourapp == test_data.churn).sum().astype(float) / len(test_data_nolab)*100
print("agModel prediction accuracy is %3.2f" %(accuracy))
# Out:
# agModel prediction accuracy is 96.00

# %%
#result = loadinyourapp.predict(test_data_nolab, model='CatboostClassifier')
result = loadinyourapp.predict(test_data_nolab, model='LightGBMLarge')
result
# Out:
# 3284     no
# 1025     no
# 2388    yes
# 3480     no
# 846      no
#        ...
# 3454     no
# 3605    yes
# 1267     no
# 3174    yes
# 1677     no
# Name: churn, Length: 850, dtype: object

# %%
accuracy = (result == test_data.churn).sum().astype(float) / len(test_data_nolab)*100
print("agModel prediction accuracy is %3.2f" %(accuracy))
# Out:
# agModel prediction accuracy is 96.24

# %% [markdown]
# ## Behind the fit function
#
# #### Data preprocessing
# 1. Classification 문제인지 regression 문제인지 결정
# 2. Feature를 numeric, categorical, text, or date/time 타입으로 분류하고 전처리
#     - categorical 변수이지만 반복되지 않는 컬럼은 삭제함 (예: user_id 컬럼)
#     - text 컬럼은 n-gram 으로, date/time은 적절한 숫자 타입으로 변환 등
#     - missing 데이터는 unkown으로 채움
# 3. Training set/ validation set 분리
#
#
# #### Model fitting
# - random forest처럼 범용적인 알고리즘부터 try하고 knn같은것은 나중에 시도함
# - 제약사항이 없이 가장 정확한 모델리턴 or 비용/시간 제한을 주고 최고 정확성 모델 리턴
# - 앙상블 and multi-layer stacking을 이용한 결합
# - 하이퍼파라미터 최적화
#
#
# #### Algorithms
# - 알고리즘 구성
#     1. [Random Forests](https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.RandomForestClassifier.html)
#     2. [Extremely Randomized trees](https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.ExtraTreesClassifier.html)
#     3. [k-nearest neighbors](https://scikit-learn.org/stable/modules/neighbors.html)
#     4. [LightGBM boosted trees](https://lightgbm.readthedocs.io/en/latest/)
#     5. [CatBoost boosted trees](https://github.com/catboost/catboost)
#     6. AutoGluon-Tabular deep neural networks
#
#
# #### AutoGluon DNN 네트워크 아키텍처
# <img src="https://d2908q01vomqb2.cloudfront.net/ca3512f4dfa95a03169c5a670a4c91a19b3077b4/2020/03/30/autogluon_f2.png" width='500' >
#
# - embedding layer가 있는 것이 특징
#
# #### Ensembles and multi-layer stacking
# <img src="https://d2908q01vomqb2.cloudfront.net/ca3512f4dfa95a03169c5a670a4c91a19b3077b4/2020/03/30/autogluon_f3-1024x744.png" width='430' >
#
# - Base layer: n개(현재 6개)의 모델로 개별 학습
# - Concat layer: 각 모델의 예측 결과를 input 값과 함께 합치기
# - Stacker layer: concat layer의 결과를 입력으로 다수의 stacker 모델을 이용하여 학습 실행. 이 때 base layer의 모델들을 재사용함(하이퍼파라미터 포함
# - Weighting layer: stacker layer의 결과는 새로운 ensamble모델을 이용하여 validation set의 정확도를 높일도록 다시 합쳐짐
